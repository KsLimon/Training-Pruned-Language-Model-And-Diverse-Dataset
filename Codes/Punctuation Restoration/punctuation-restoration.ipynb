# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/xashru/punctuation-restoration
# Out:
# Cloning into 'punctuation-restoration'...
# remote: Enumerating objects: 279, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 279 (delta 0), reused 1 (delta 0), pack-reused 276
# Receiving objects: 100% (279/279), 10.96 MiB | 14.03 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
ls
# Out:
# drive/  punctuation-restoration/  sample_data/

# %%
cd punctuation-restoration
# Out:
# /content/punctuation-restoration

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 674 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 44.5 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 54.7 MB/s
# ...
#      |████████████████████████████████| 880 kB 60.2 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=2a09d1fdd5138fa905429dd90e18214e6182ccd3881244c5eaa6d0406b19da7a
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python src/train.py --cuda=True --pretrained-model=/content/drive/MyDrive/Models/pet_bnbert/p0-i0 --freeze-bert=False --lstm-dim=-1 \
--language=bangla --seed=1 --lr=5e-6 --epoch=10 --use-crf=False --augment-type=all --augment-rate=0.15 \
--alpha-sub=0.4 --alpha-del=0.4 --data-path=data --save-path=out
# Out:
# train: 100% 784/784 [00:45<00:00, 17.40it/s]
# epoch: 0, Train loss: 0.4777245362650375, Train accuracy: 0.8765776550528452
# eval: 100% 103/103 [00:02<00:00, 48.67it/s]
# epoch: 0, Val loss: 0.42635347166107695, Val accuracy: 0.8826645894448404
# train: 100% 784/784 [00:44<00:00, 17.67it/s]
# epoch: 1, Train loss: 0.3840000206338508, Train accuracy: 0.8833688559457923
# eval: 100% 103/103 [00:02<00:00, 47.73it/s]
# epoch: 1, Val loss: 0.5360658808240613, Val accuracy: 0.7986973167376569
# train: 100% 784/784 [00:45<00:00, 17.21it/s]
# epoch: 2, Train loss: 0.30110552416620207, Train accuracy: 0.8921881841623015
# eval: 100% 103/103 [00:02<00:00, 47.58it/s]
# epoch: 2, Val loss: 0.4003010603409369, Val accuracy: 0.8731182082856843
# train: 100% 784/784 [00:46<00:00, 16.79it/s]
# epoch: 3, Train loss: 0.2744749198686712, Train accuracy: 0.8994861793220161
# eval: 100% 103/103 [00:02<00:00, 44.36it/s]
# epoch: 3, Val loss: 0.37132797976141996, Val accuracy: 0.868930617476286
# ...
