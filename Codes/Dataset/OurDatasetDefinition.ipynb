# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9bec691-665d-4f54-bbec-9ab26d4e8f16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9bec691-665d-4f54-bbec-9ab26d4e8f16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving full_corpas.csv to full_corpas.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
csv_file = input('full_corpas.csv')
txt_file = input('full_corpas.txt')

text_list = []

with open(csv_file, "r") as my_input_file:
    for line in my_input_file:
        line = line.split(",", 2)
        text_list.append(" ".join(line))

with open(txt_file, "w") as my_output_file:
    my_output_file.write("#1\n")
    my_output_file.write("double({},{})\n".format(len(text_list), 2))
    for line in text_list:
        my_output_file.write("  " + line)
    print('File Successfully written.')
# Out:
# full_corpas.csv/content/full_corpas.csv
# full_corpas.txt/content/full_corpas.txt
# File Successfully written.

# %% [markdown]
# **Tokenizer**
# ---

# %%
import string
import io
import codecs

# %%
def load_doc(filename):
    with io.open(filename, 'r', encoding='utf8') as f:
        text = f.read()
    return text

# %%
doc = load_doc("/content/drive/MyDrive/Shadhu _Kobita/full_data.txt")

# %%
def clean_doc(doc):
    # replace '--' with a space ' '
    doc = doc.replace('?', ' ? ')
    doc = doc.replace('।', '')
    doc = doc.replace(',', ' । ')
    doc = doc.replace('-', ' । ')
    doc = doc.replace('(', ' । ')
    doc = doc.replace(')', ' । ')
    doc = doc.replace('{', ' । ')
    doc = doc.replace('}', ' । ')
    doc = doc.replace('[', ' । ')
    doc = doc.replace(']', ' । ')
    doc = doc.replace('*', ' ')
    doc = doc.replace('^', ' ')
    doc = doc.replace('#', ' ')
    doc = doc.replace('~', ' ')
    doc = doc.replace('`', ' ')
    doc = doc.replace('/', ' ')
    doc = doc.replace('_', ' ')
    doc = doc.replace('’', ' ')
    doc = doc.replace('‘', ' ')
    doc = doc.replace('.', ' । ')
    
    
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    #table = str.maketrans('', '', string.punctuation)
    #tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    #tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    return tokens

# %%
tokens = clean_doc(doc)
#tokens = doc
print(tokens[:200])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# Out:
# ['আজকের', 'এইদিনে', 'জন্মগ্রহণ', 'করায়', 'পাশ্চাত্যমতে', 'আপনি', 'ধনু', 'রাশির', 'জাতব্যক্তি', 'আপনার', 'ওপর', 'আজ', 'রাশি', 'অধিপতি', 'বৃহস্পতি', 'সর্বগ্রাসী', 'গ্রহ', 'রাহু', 'ও', 'পরমযোগী', 'গ্রহ', 'শনি', 'মহারাজের', 'প্রভাব', 'বিদ্যমান', 'আপনার', 'সঙ্গে', 'মিথুন', 'রাশির', 'বন্ধুত্ব', 'শুভফল', 'প্রদান', 'করবে', 'জীবনসাথী', '।', 'শ্বশুরালয়', 'ও', 'মাতুলালয়', 'থেকে', 'ভরপুর', 'সাহায্য', '।', 'সহযোগিতাপ্রাপ্ত', 'হবেন', 'দ্রুতগতির', 'ব্রিটিশদের', 'উপনিবেশ', 'বিভাজন', 'নীতির', 'ফসল', 'পাকিস্তানের', 'পথচলাটা', 'স্বাভাবিকের', 'চেয়ে', 'অনেক', 'কঠিন', 'ছিল', 'এর', 'মূল', 'কারণ', 'দেশটির', 'পূর্বাংশ', 'মহান', 'বিজয়ের', 'মাস', 'নিয়ে', 'আপনার', 'অভিব্যক্তি', '।', '।', '।', 'বিজয়ের', 'মাসে', 'সবাইকে', 'আমার', 'প্রাণঢালা', 'ভালোবাসা', 'আর', 'শুভেচ্ছা', 'এই', 'মাস', 'এলেই', 'মনটা', 'গর্বে', 'ভরে', 'যায়', 'চাই', 'সবাই', 'দেশকে', 'ভালোবাসুন', '।', 'মুক্তিযোদ্ধাদের', 'পাশে', 'থাকুন', 'আমি', 'দেশের', 'তরে', 'প্রাণ', 'উত্সর্গকৃত', 'সব', 'বীর', 'মুক্তিযোদ্ধার', 'প্রতি', 'শ্রদ্ধা', 'ও', 'ভালোবাসা', 'জানাচ্ছি', 'ডিসেম্বর', 'মাসে', 'ব্যস্ততা', '।', '।', '।', 'কিছুদিন', 'তাদের', 'বিয়ে', 'নিয়ে', 'দীর্ঘদিনের', 'জল্পনার', 'অবসান', 'হলো', 'ইতালির', 'তাস্কানিতে', 'হিন্দু', 'মতে', 'বিয়ে', 'হলো', 'বিরাট', 'কোহলি', 'আর', 'আনুশকা', 'শর্মার', '১৪', 'ডিসেম্বর', 'মহান', 'বুদ্ধিজীবী', 'দিবসকে', 'সামনে', 'রেখে', 'নির্মিত', 'হলো', 'বিশেষ', 'নাটক', 'অভিমান', 'এটি', 'পরিচালনা', 'করেছেন', 'আবু', 'হায়াত', 'মাহমুদ', 'এই', 'বছরটা', 'দারুণ', 'কাটল', 'ইরফান', 'খানের', 'তার', 'শেষ', 'দুটি', 'ছবি', 'হিন্দি', 'মিডিয়াম', 'আর', 'করিব', 'করিব', 'সিঙ্গল', 'বক্স', 'অফিসে', 'আশাতীত', 'সাফল্য', 'পেয়েছে', 'আবারও', 'হলিউডে', 'পা', 'দিচ্ছেন', 'তিনি', 'ইরফানের', 'পরবর্তী', 'ছবি', 'পাজল', 'সানডেন', 'ফিল্ম', 'ফেস্টিভ্যালে', 'প্রিমিয়ার', 'হচ্ছে', 'স্বভাবতই', 'এই', 'খবরে', 'খুশি', 'হিন্দি', 'ছবির', 'এই', 'স্টার', 'ইরফান', 'বলছেন', '।', 'ওই', 'ওয়ার্ল্ড', 'প্রিমিয়ার', 'নোলক']
# Total Tokens: 4934294
# Unique Tokens: 209546
