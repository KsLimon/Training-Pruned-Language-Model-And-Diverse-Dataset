# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ldc = pd.read_csv("/content/drive/MyDrive/Datasets/LDC/LDC_IITKGP.csv")

ldc.columns = ['id', 'word', 'tag']

ldc.head()
# Out:
#    id      word  tag
# 0   0  ﻿রপ্তানি   JJ
# 1   1    দ্রব্য   NC
# 2   2         -   PU
# 3   3      তাজা   JJ
# 4   4         ও  CCD

# %%
ldc.drop('id', inplace=True, axis=1)
ldc.head()
# Out:
#        word  tag
# 0  ﻿রপ্তানি   JJ
# 1    দ্রব্য   NC
# 2         -   PU
# 3      তাজা   JJ
# 4         ও  CCD

# %%
ldc.to_csv("ldc_iitkgp.csv")

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/pos/pos_tag_data_bangla_tagged_corpus.tsv",encoding='utf-8', header=None, delimiter="\t")

df.columns = ['word', 'tag']

df.head()
# Out:
#          word tag
# 0       শহরের  NC
# 1  চাকলাপাড়ার  NP
# 2        একটি  JQ
# 3        বাড়ি  NC
# 4        থেকে  PP

# %%
df.to_csv("df.csv")

# %%
import pandas as pd
  
# merging two csv files
df = pd.concat(
    map(pd.read_csv, ["/content/ldc_iitkgp.csv", "/content/df.csv"]), ignore_index=True)

df.to_csv("/content/drive/MyDrive/Datasets/LDC/LDC_IITKGP_CRBLP.csv", index=False)
